# %%
import torch
x = torch.randn((8, 3,128, 128))

# %%
x.shape
# Out:
# torch.Size([8, 3, 128, 128])

# %%
for img in x:
    print(img.unsqueeze(0).shape)
# Out:
# torch.Size([1, 3, 128, 128])
# torch.Size([1, 3, 128, 128])
# torch.Size([1, 3, 128, 128])
# torch.Size([1, 3, 128, 128])
# torch.Size([1, 3, 128, 128])
# torch.Size([1, 3, 128, 128])
# torch.Size([1, 3, 128, 128])
# torch.Size([1, 3, 128, 128])
